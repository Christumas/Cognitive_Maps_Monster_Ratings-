# %%
import pandas as pd
import numpy as np
from PIL import Image
import itertools
import os
import random

# %%
Stimdirectory = 'C:\JS Psych Experiments\Monster Ratings\monsters'
Stimuli = [filename for filename in os.listdir(Stimdirectory) if filename.endswith(('.jpeg', '.png'))] #get all the stimuli file names
#find all possible unique combinations of stimuli
uniquepairings = list(itertools.combinations(Stimuli,2)) #this list of unique pairings then can be shuffled for each participant

# %%
DesignFile = {'Participant':[],
              'Block':[],
              'Trial':[],
              'StimLeft':[],
              'StimRight':[],
              'Response':[],
} #basic structure of the design file

Dataframe = pd.DataFrame(DesignFile) 
Dataframe

#lets create a design file generator
NumParticipants =  1
NumTrials = len(uniquepairings)
NumBlocks = 1

for participant in range(NumParticipants): #specify the number of iterations (design files) based off the number of participants
    Dataframe['Participant'] = np.repeat(participant, NumTrials)
    Dataframe['Block'] = np.repeat(NumBlocks, NumTrials)
    Dataframe['Trial'] = range(NumTrials) 
    Dataframe['Trial'] += 1
    
    shuffledPairs = [] #variable to hold the set of shuffled unique pairings
    #lets shuffle the contents of the pairs themselves
    for i in uniquepairings: #loop through all the unique pairings
        pair = list(i) #convert it to list so we can use shuffle
        random.shuffle(pair) #we shuffle the contents inside each pair
        shuffledPairs.append(tuple(pair)) 
    
    random.shuffle(shuffledPairs) #then shuffle the entire list of unique pairs
    
    #assign the left and right stimulus to be shown
    Dataframe['StimLeft'] = [i[0] for i in shuffledPairs]
    Dataframe['StimRight'] = [i[1] for i in shuffledPairs]
    
    
    if participant <= 9:
        Dataframe.to_csv(f'DesignFiles/PP0{participant+1}.csv')
        
    if participant >=10:
        Dataframe.to_csv(f'DesignFiles/PP{participant}.csv')
        
    
    

Dataframe
# Out:
#     Participant  Block  Trial   StimLeft  StimRight  Response
# 0             0      1      1  obj03.png  obj12.png       NaN
# 1             0      1      2  obj14.png  obj06.png       NaN
# 2             0      1      3  obj12.png  obj01.png       NaN
# 3             0      1      4  obj01.png  obj20.png       NaN
# 4             0      1      5  obj04.png  obj11.png       NaN
# ..          ...    ...    ...        ...        ...       ...
# 86            0      1     87  obj04.png  obj07.png       NaN
# 87            0      1     88  obj09.png  obj05.png       NaN
# 88            0      1     89  obj05.png  obj14.png       NaN
# 89            0      1     90  obj01.png  obj00.png       NaN
# 90            0      1     91  obj14.png  obj01.png       NaN
#
# [91 rows x 6 columns]
